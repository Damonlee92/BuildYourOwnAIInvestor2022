# %% [markdown]
# # Exercise 6 – Pandas Basics

# %%
# Set the plotting DPI settings to be a bit higher.
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [8.0, 5.0]
plt.rcParams['figure.dpi'] = 150

# %%
#Import Pandas
import pandas as pd

# %%
#Creating a dictionary with some table data in it.
dict = {
    'Name':['Tom', 'Dick', 'Harry'],
    'Age':[24, 35, 29],
    'Shoe Size':[7,8,9]
}

# %%
#Creating a DataFrame with the data from the dictionary
df=pd.DataFrame(dict)

# %%
#The dataframe can be viewed without the print() command.
df
# Out:
#     Name  Age  Shoe Size
# 0    Tom   24          7
# 1   Dick   35          8
# 2  Harry   29          9

# %%
#Write the data from the DataFrame to a file
df.to_csv('people.csv')

# %%
# Now I want to read the data, lets create a new DataFrame. Remember to specify an index column!
my_data=pd.read_csv('people.csv', index_col=0)

# %%
#have a look at the data
my_data
# Out:
#     Name  Age  Shoe Size
# 0    Tom   24          7
# 1   Dick   35          8
# 2  Harry   29          9

# %% [markdown]
# # Read in SimFin data

# %% [markdown]
# ## First Getting Stock Data
# Get csv data from [simfin.com](https://simfin.com/data/bulk). The following download settings were used.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Lets read some income statement data from SimFin (https://simfin.com/)
# Your download directory will differ.

# You can specify a full directory address
fullDirectoryAddr = 'C:/Users/G50/Stock_Data/SimFin/us-income-annual/us-income-annual.csv'

# Or, if reading from current directory
currDirectoryAddr = 'us-income-annual.csv'

# Reading the .csv file into a DataFrame
Income_Data = pd.read_csv(currDirectoryAddr, 
                          delimiter=';')

# %%
# Get the DataFrame shape (Might be useful for other computation)
print('DataFrame shape is: ',Income_Data.shape)
# Have a look at what our DataFrame looks like
Income_Data
# You will notice that thefirst few and last few items are shown (Jupyter doesn't want to display all 15,124 rows.)
# Out:
# DataFrame shape is:  (10888, 28)
#       Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 0          A     45846      USD         2016            FY  2016-10-31
# 1          A     45846      USD         2017            FY  2017-10-31
# 2          A     45846      USD         2018            FY  2018-10-31
# 3          A     45846      USD         2019            FY  2019-10-31
# 4          A     45846      USD         2020            FY  2020-10-31
# ...      ...       ...      ...          ...           ...         ...
# 10883   ZYXI    171401      USD         2016            FY  2016-12-31
# 10884   ZYXI    171401      USD         2017            FY  2017-12-31
# 10885   ZYXI    171401      USD         2018            FY  2018-12-31
# 10886   ZYXI    171401      USD         2019            FY  2019-12-31
# 10887   ZYXI    171401      USD         2020            FY  2020-12-31
#
#       Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 0       2016-12-20    2018-12-20     326000000.0       329000000.0  ...
# 1       2017-12-21    2018-12-20     322000000.0       326000000.0  ...
# 2       2018-12-20    2020-12-18     321000000.0       325000000.0  ...
# 3       2019-12-19    2021-12-17     314000000.0       318000000.0  ...
# 4       2020-12-18    2021-12-17     309000000.0       312000000.0  ...
# ...            ...           ...             ...               ...  ...
# 10883   2017-04-18    2018-02-28      34398357.0        34398357.0  ...
# 10884   2018-02-28    2019-02-26      35371600.0        36515600.0  ...
# 10885   2019-02-26    2019-02-26      35753300.0        37447300.0  ...
# 10886   2020-02-27    2021-02-25      35682900.0        37359300.0  ...
# 10887   2021-02-25    2022-03-22      37255900.0        38437300.0  ...
#
#        Non-Operating Income (Loss)  Interest Expense, Net  \
# 0                      -71000000.0            -61000000.0
# 1                      -38000000.0            -57000000.0
# 2                       42000000.0            -37000000.0
# 3                      -22000000.0            -38000000.0
# 4                       -4000000.0            -70000000.0
# ...                            ...                    ...
# 10883                    -556000.0              -352000.0
# 10884                   -1450000.0             -1450000.0
# 10885                    -154000.0              -154000.0
# 10886                      -5000.0                -5000.0
# 10887                     -19000.0               -19000.0
#
#        Pretax Income (Loss), Adj.  Abnormal Gains (Losses)  \
# 0                       544000000                      NaN
# 1                       803000000                      NaN
# 2                       946000000                      NaN
# 3                       919000000                      NaN
# 4                       842000000                      NaN
# ...                           ...                      ...
# 10883                       84000                      NaN
# 10884                     7494000                      NaN
# 10885                    10216000                      NaN
# 10886                    11061000                 880000.0
# 10887                    10230000                 -77000.0
#
#        Pretax Income (Loss)  Income Tax (Expense) Benefit, Net  \
# 0                 544000000                        -82000000.0
# 1                 803000000                       -119000000.0
# 2                 946000000                       -630000000.0
# 3                 919000000                        152000000.0
# 4                 842000000                       -123000000.0
# ...                     ...                                ...
# 10883                 84000                           -15000.0
# 10884               7494000                          -129000.0
# 10885              10216000                          -664000.0
# 10886              11941000                         -2449000.0
# 10887              10153000                         -1079000.0
#
#        Income (Loss) from Continuing Operations  \
# 0                                     462000000
# 1                                     684000000
# 2                                     316000000
# 3                                    1071000000
# 4                                     719000000
# ...                                         ...
# 10883                                     69000
# 10884                                   7365000
# 10885                                   9552000
# 10886                                   9492000
# 10887                                   9074000
#
#        Net Extraordinary Gains (Losses)  Net Income  Net Income (Common)
# 0                                   NaN   462000000            462000000
# 1                                   NaN   684000000            684000000
# 2                                   NaN   316000000            316000000
# 3                                   NaN  1071000000           1071000000
# 4                                   NaN   719000000            719000000
# ...                                 ...         ...                  ...
# 10883                               NaN       69000                69000
# 10884                               NaN     7365000              7365000
# 10885                               NaN     9552000              9552000
# 10886                               NaN     9492000              9492000
# 10887                               NaN     9074000              9074000
#
# [10888 rows x 28 columns]

# %%
# The headings of columns are called keys. 
# The columns themselves are called series.
# To see what all the columns are in our dataframe, use the .keys() function. 
print(Income_Data.keys())
# Out:
# Index(['Ticker', 'SimFinId', 'Currency', 'Fiscal Year', 'Fiscal Period',
#        'Report Date', 'Publish Date', 'Restated Date', 'Shares (Basic)',
#        'Shares (Diluted)', 'Revenue', 'Cost of Revenue', 'Gross Profit',
#        'Operating Expenses', 'Selling, General & Administrative',
#        'Research & Development', 'Depreciation & Amortization',
#        'Operating Income (Loss)', 'Non-Operating Income (Loss)',
#        'Interest Expense, Net', 'Pretax Income (Loss), Adj.',
#        'Abnormal Gains (Losses)', 'Pretax Income (Loss)',
#        'Income Tax (Expense) Benefit, Net',
#        'Income (Loss) from Continuing Operations',
#        'Net Extraordinary Gains (Losses)', 'Net Income',
#        'Net Income (Common)'],
#       dtype='object')

# %%
# To see series data for a single key:
Income_Data['Ticker']
# Out:
# 0          A
# 1          A
# 2          A
# 3          A
# 4          A
#         ...
# 17124    low
# 17125    low
# 17126    low
# 17127    low
# 17128    low
# Name: Ticker, Length: 17129, dtype: object

# %%
Income_Data['Report Date']
# Out:
# 0        2008-10-31
# 1        2009-10-31
# 2        2010-10-31
# 3        2011-10-31
# 4        2012-10-31
#             ...
# 17124    2016-02-29
# 17125    2017-02-28
# 17126    2018-02-28
# 17127    2019-02-28
# 17128    2020-02-29
# Name: Report Date, Length: 17129, dtype: object

# %%
print('The resulting type of object from our series selection is a:', 
      type(Income_Data['Report Date']) )

print('using .values after our selection turns this into a:', 
      type(Income_Data['Report Date'].values) )
# Out:
# The resulting type of object from our series selection is a: <class 'pandas.core.series.Series'>
# using .values after our selection turns this into a: <class 'numpy.ndarray'>

# %%
# To get a list of tickers that exist, we could use the set operations we learned earlier.
my_set = set(Income_Data['Ticker'].values)
print(my_set)
# Out:
# {'SHPGF', 'CWH', 'MAS', 'RAVN', 'LNTH', 'HALO', 'DKS', 'DPLO', 'K', 'GIMO', 'SLQT', 'VCSA', 'DLB', 'MSM', 'IRM', 'VIVE', 'DOCN', 'SFLY', 'RDC', 'CULP', 'SEER', 'MNI', 'SD', 'STMP', 'BH', 'EXP', 'INSW', 'GCI', 'FONR', 'DOCU', 'DYN_delist', 'ORGO', 'DZSI', 'OLLI', 'CRSP', 'HEI', 'IDCC', 'QTNA', 'UIS', 'AC', 'HEAR', 'FGP', 'MBOT', 'TXMD', 'LGIH', 'ZDGE', 'VIRC', 'EVR', 'PSFE', 'SSNI', 'PEN', 'DESTQ', 'ETM', 'IPG', 'SNPS', 'FIT', 'AMZN', 'DSKE', 'NTIP', 'LYB', 'CVT', 'FND', 'CLH', 'AVNW', 'DUOL', 'EVC', 'LOV', 'NVR', 'PEB', 'SONO', 'SOFO', 'XOM', 'UPWK', 'MGLN', 'OTEX', 'XLNX', 'OSK', 'IDT', 'MB', 'ARAY', 'LEAT', 'LAYN', 'TAYD', 'AVYA', 'KSS', 'RL', 'FCEL', 'ULTA', 'NRG', 'ENV', 'LSCC', 'CTAS', 'DYN', 'UDR', 'IMGO', 'KMT', 'SNH', 'IMPV', 'FIX', 'SCSC', 'VERI', 'WING', 'DAR', 'TCRT', 'IVZ', 'CBI', 'OCN', 'KDP', 'MDXG', 'MRTX', 'VNTV', 'SNDR', 'BOOM', 'SCG', 'AKAM', 'VRNT', 'FUL', 'SGM', 'FELE', 'FLGT', 'FHI', 'ADM', 'FSLY', 'SDC', 'CBOE', 'TPCO', 'MYMD', 'VRNS', 'RYN', 'BCOR', 'LEGH', 'XCO', 'VSTO', 'FTV', 'BSTG', 'FDC', 'CGA', 'GDOT', 'CNS', 'DAL', 'EQIX', 'NEPH', 'POOL', 'CCI', 'RGEN', 'ROP', 'CDMO', 'AMPL', 'HEP', 'GD', 'SWKS', 'LNT', 'MLI', 'HIW', 'RIOT', 'ORLY', 'CHD', 'ASGN', 'SAVE', 'SSNT', 'VIR', 'WHR', 'AGI', 'HOG', 'WDAY', 'SMIT', 'ONEM', 'BBBY', 'HSII', 'BZH', 'AON', 'ARG', 'BBGI', 'GEVO', 'GEL', 'TTMI', 'DISCA', 'GNRC', 'HST', 'HZO', 'AXTA', 'TTEK', 'MSA', 'ARQL', 'ICUI', 'REN', 'KPTI', 'WSCI', 'EEFT', 'KO', 'ITI', 'LIVN', 'PAYC', 'DOMO', 'GCO', 'X', 'CRWS', 'XYL', 'ASTC', 'CVX', 'PCG', 'MATX', 'IOTS', 'AGIO', 'PLCE', 'VLO', 'CWT', 'NOC', 'BOXL', 'HFC', 'TEL', 'AAWW', 'ZI', 'SYNH', 'MMP', 'CMI', 'LAKE', 'PVAC', 'EVOP', 'CENT', 'NBL', 'COTY', 'DXPE', 'O', 'HDP', 'ABNB', 'ENBL', 'TR', 'SIG', 'GH', 'EPE', 'CMTL', 'MASS', 'QNST', 'SQBG', 'MXPT', 'RBBN', 'FC', 'ATI', 'ISDR', 'INFO', 'MICR', 'WMK', 'GSEG', 'ABSI', 'MNRO', 'DG', 'FNSR', 'LEAF', 'R', 'ZS', 'COGT', 'HTZ', 'FDS', 'REZI', 'PTON', 'DEI', 'BKTI', 'LLY', 'SNX', 'DBD', 'OA', 'MAC', 'GWW', 'BRBR', 'AMKR', 'CRL', 'PGTI', 'BRO', 'ANF', 'AGCO', 'TTPH', 'ZVO', 'STAG', 'PCVX', 'RUN', 'KANP', 'RIGL', 'LW', 'REXR', 'MXWL', 'HCOM', 'HES', 'JBL', 'FDX', 'RES', 'ALV', 'PKI', 'MUR', 'WW', 'UHS', 'ECYT', 'ZEUS', 'USX', 'SUPN', 'REGN', 'ATUS', 'OHI', 'TREX', 'ACAN', 'EMN', 'SLB', 'WKHS', 'AGYS', 'NTCT', 'TESO', 'DLPH', 'AVP', 'DVAX', 'MIK', 'MNK', 'SNOW', 'GMED', 'BKD', 'PLAB', 'MOS', 'PX', 'TOY_delist', 'GPS', 'KW', 'CLC', 'LECO', 'ITGR', 'FLS', 'TREE', 'AXL', 'DOC', 'PJT', 'AEE', 'SNA', 'CYAN', 'EE', 'REV', 'BLD', 'BCPC', 'VIA', 'ABAX', 'ADS', 'SCCO', 'CNXR', 'CORT', 'FTK', 'T', 'MRCY', 'CENX', 'WES', 'JNPR', 'WMB', 'AMG', 'EGLT', 'JJSF', 'CRNC', 'ALB', 'UGI', 'BOOT', 'FOR', 'SAIL', 'ALKS', 'IVTY', 'FR', 'OGS', 'RMBL', 'PSX', 'OUT', 'ALSN', 'SUI', 'BF-A', 'FLXS', 'NWE', 'AINC', 'RCKY', 'PH', 'MHK', 'IFF', 'FBRX', 'MIDD', 'PRO', 'MARK', 'ASPN', 'SHO', 'WYNN', 'CPN', 'CMS', 'BLI', 'CSOD', 'MEET', 'AKR', 'DBI', 'NARI', 'TACO', 'ELS', 'BRCD', 'ES', 'ERS', 'ACU', 'AMN', 'FNKO', 'CPT', 'ARLO', 'FROG', 'ALNY', 'HLF', 'NTRI', 'DLTR', 'LHCG', 'ICLR', 'RCII', 'MKSI', 'ACET_delis', 'CRVS', 'EHC', 'NUVA', 'NVAX', 'ABC', 'EVH', 'LSXMA', 'HAIN', 'DDS', 'ISIL', 'VGR', 'CAGU', 'CLVT', 'HOFT', 'NTAP', 'SCI', 'MLM', 'NXPI', 'ABBV', 'BPMP', 'REAL', 'VZ', 'XPEL', 'CIDM', 'KRA', 'KURA', 'RIO', 'IIPR', 'BIO', 'RIVN', 'VTVT', 'WINA', 'NUAN', 'SIGM', 'CCF', 'OTEL', 'TVPT', 'GRC', 'KLXI', 'SGEN', 'AP', 'ITOS', 'HMTV', 'CAG', 'KTWO', 'PPSI', 'RYAM', 'CALX', 'CCFI', 'WNC', 'XRAY', 'CLSK', 'KEM', 'JBLU', 'SPLK', 'ACET', 'ATW', 'BNFT', 'CL', 'ARNC', 'ONVO', 'STLD', 'MCO', 'JYNT', 'VRSN', 'BTAI', 'CRSR', 'TRGP', 'NCLH', 'AGS', 'STAA', 'SGMA', 'EXA', 'FPH', 'MHH', 'EQT', 'CF', 'SWN', 'SXC', 'V', 'BHR', 'LEVI', 'VIDE', 'ZUMZ', 'CCO', 'HLI', 'KND', 'MOBL', 'ALK', 'BG', 'ATR', 'GIII', 'AREX', 'LKSD', 'BXC', 'VXRT', 'OPTT', 'SHOO', 'TCMD', 'KMX', 'NCSO', 'SPPI', 'IPHI', 'CFLT', 'BMI', 'OLED', 'ARW', 'SNCE', 'SPB', 'ANVS', 'ASYS', 'TLRY', 'ARTEC', 'SLG', 'IEX', 'HRC', 'LPSN', 'RGLS', 'CASY', 'DLTH', 'RDNT', 'RIG',  ...

# %%
len(my_set)
# Out:
# 2504

# %%
#Alternatively a dataframe has a function .unique()
Income_Data['Ticker'].unique()
# Out:
# array(['A', 'AA', 'AAC', ..., 'ZYNE', 'ZYXI', 'low'], dtype=object)

# %%
# You can use logic on dataframes to obtain a list of boolean values that say whether a rule is True or False for each row.
# Let's try and isolate financial data for the 2017 fiscal period. 
# We will do a boolean check on items in the 'Fiscal Year' column:

IsIt2017 = (Income_Data['Fiscal Year'] == 2017)
print('The boolean logic on the Fiscal Year column is: ', IsIt2017)
# Out:
# The boolean logic on the Fiscal Year column is:  0        False
# 1         True
# 2        False
# 3        False
# 4        False
#          ...
# 10883    False
# 10884     True
# 10885    False
# 10886    False
# 10887    False
# Name: Fiscal Year, Length: 10888, dtype: bool

# %%
# We can use this list of booleans to make a smaller dataframe with only data from fiscal year 2017 as follows:
Income_Data[IsIt2017]
# Out:
#       Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 1          A     45846      USD         2017            FY  2017-10-31
# 8         AA    367153      USD         2017            FY  2017-12-31
# 14       AAL     68568      USD         2017            FY  2017-12-31
# 19      AAMC    847094      USD         2017            FY  2017-12-31
# 23       AAN    441241      USD         2017            FY  2017-12-31
# ...      ...       ...      ...          ...           ...         ...
# 10864   ZUMZ     45730      USD         2017            FY  2018-01-31
# 10868    ZUO    994625      USD         2017            FY  2018-01-31
# 10873    ZVO    901866      USD         2017            FY  2017-12-31
# 10879   ZYNE    901704      USD         2017            FY  2017-12-31
# 10884   ZYXI    171401      USD         2017            FY  2017-12-31
#
#       Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 1       2017-12-21    2018-12-20     322000000.0       326000000.0  ...
# 8       2018-02-26    2019-02-26     184000000.0       187000000.0  ...
# 14      2018-02-21    2019-02-25     489164000.0       491692000.0  ...
# 19      2018-03-01    2018-03-01       1570428.0         1570428.0  ...
# 23      2018-03-01    2019-02-14      70837000.0        72121000.0  ...
# ...            ...           ...             ...               ...  ...
# 10864   2018-03-19    2018-03-19      24679000.0        24878000.0  ...
# 10868   2018-03-15    2020-03-31      26563000.0        26563000.0  ...
# 10873   2018-02-21    2019-03-12      32058000.0        32794000.0  ...
# 10879   2018-03-12    2019-03-11      12914814.0        12914814.0  ...
# 10884   2018-02-28    2019-02-26      35371600.0        36515600.0  ...
#
#        Non-Operating Income (Loss)  Interest Expense, Net  \
# 1                      -38000000.0            -57000000.0
# 8                     -131000000.0           -104000000.0
# 14                    -836000000.0           -959000000.0
# 19                       1086000.0                    0.0
# 23                     -15122000.0            -18703000.0
# ...                            ...                    ...
# 10864                    -357000.0               495000.0
# 10868                     252000.0               252000.0
# 10873                    1511000.0                    NaN
# 10879                     810705.0               519554.0
# 10884                   -1450000.0             -1450000.0
#
#        Pretax Income (Loss), Adj.  Abnormal Gains (Losses)  \
# 1                       803000000                      NaN
# 8                      1468000000             -309000000.0
# 14                     3395000000                      NaN
# 19                       -6261000                      0.0
# 23                      257571000              -17994000.0
# ...                           ...                      ...
# 10864                    48403000                      NaN
# 10868                   -37826000                      NaN
# 10873                    16619000               -8682000.0
# 10879                   -32012304                      0.0
# 10884                     7494000                      NaN
#
#        Pretax Income (Loss)  Income Tax (Expense) Benefit, Net  \
# 1                 803000000                      -1.190000e+08
# 8                1159000000                      -6.000000e+08
# 14               3395000000                      -2.113000e+09
# 19                 -6261000                      -7.080000e+05
# 23                239577000                       5.295900e+07
# ...                     ...                                ...
# 10864              48403000                      -2.160100e+07
# 10868             -37826000                      -1.551000e+06
# 10873               7937000                       1.174000e+06
# 10879             -32012304                       0.000000e+00
# 10884               7494000                      -1.290000e+05
#
#        Income (Loss) from Continuing Operations  \
# 1                                     684000000
# 8                                     559000000
# 14                                   1282000000
# 19                                     -6969000
# 23                                    292536000
# ...                                         ...
# 10864                                  26802000
# 10868                                 -39377000
# 10873                                   9111000
# 10879                                 -32012304
# 10884                                   7365000
#
#        Net Extraordinary Gains (Losses)  Net Income  Net Income (Common)
# 1                                   NaN   684000000            684000000
# 8                                   NaN   217000000            217000000
# 14                                  NaN  1282000000           1282000000
# 19                                  NaN    -6969000             -7175000
# 23                                  NaN   292536000            292536000
# ...                                 ...         ...                  ...
# 10864                               NaN    26802000             26802000
# 10868                               NaN   -39377000            -39377000
# 10873                               NaN     9111000              9111000
# 10879                               NaN   -32012304            -32012304
# 10884                               NaN     7365000              7365000
#
# [2196 rows x 28 columns]

# %%
# Or if we want to do this kind of filter in a single line:
Income_Data[Income_Data['Fiscal Year'] == 2017]
# Which is basically: 'I want the rows of Income_Data where the Income_Data Fiscal Year column is 2017.'
# Notice there are only 1,726 rows instead of 15,125
# Out:
#       Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 9          A     45846      USD         2017            FY  2017-10-31
# 14        AA    367153      USD         2017            FY  2017-12-31
# 26       AAL     68568      USD         2017            FY  2017-12-31
# 33      AAMC    847094      USD         2017            FY  2017-12-31
# 44       AAN    441241      USD         2017            FY  2017-12-31
# ...      ...       ...      ...          ...           ...         ...
# 17088   ZUMZ     45730      USD         2017            FY  2018-02-28
# 17098    ZVO    901866      USD         2017            FY  2017-12-31
# 17104   ZYNE    901704      USD         2017            FY  2017-12-31
# 17114   ZYXI    171401      USD         2017            FY  2017-12-31
# 17126    low    186050      USD         2017            FY  2018-02-28
#
#       Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 9       2017-12-21    2018-12-20     322000000.0       326000000.0  ...
# 14      2018-02-26    2018-02-26     184000000.0       187000000.0  ...
# 26      2018-02-21    2018-02-21     489164000.0       491692000.0  ...
# 33      2018-03-01    2018-03-01       1570428.0         1570428.0  ...
# 44      2018-03-01    2018-03-01      70837000.0        72121000.0  ...
# ...            ...           ...             ...               ...  ...
# 17088   2018-03-19    2018-03-19      24679000.0        24878000.0  ...
# 17098   2018-02-21    2019-03-12      32058000.0        32794000.0  ...
# 17104   2018-03-12    2019-03-11      12914814.0        12914814.0  ...
# 17114   2018-02-28    2018-02-28      32156000.0        33196000.0  ...
# 17126   2018-04-02    2018-04-02     839000000.0       840000000.0  ...
#
#        Non-Operating Income (Loss)  Interest Expense, Net  \
# 9                      -38000000.0            -57000000.0
# 14                     -46000000.0           -104000000.0
# 26                    -974000000.0           -959000000.0
# 33                       1086000.0                    0.0
# 44                     -15122000.0            -18703000.0
# ...                            ...                    ...
# 17088                    -357000.0               495000.0
# 17098                    1511000.0                    NaN
# 17104                     810705.0               519554.0
# 17114                   -1450000.0             -1450000.0
# 17126                 -633000000.0           -633000000.0
#
#        Pretax Income (Loss), Adj.  Abnormal Gains (Losses)  \
# 9                       803000000                      NaN
# 14                     1468000000             -309000000.0
# 26                     3084000000                      NaN
# 33                       -6261000                      0.0
# 44                      257571000              -17994000.0
# ...                           ...                      ...
# 17088                    48403000                      NaN
# 17098                    16619000               -8682000.0
# 17104                   -32012304                      0.0
# 17114                     7494000                      NaN
# 17126                  5953000000             -464000000.0
#
#        Pretax Income (Loss)  Income Tax (Expense) Benefit, Net  \
# 9                 803000000                      -1.190000e+08
# 14               1159000000                      -6.000000e+08
# 26               3084000000                      -1.165000e+09
# 33                 -6261000                      -7.080000e+05
# 44                239577000                       5.295900e+07
# ...                     ...                                ...
# 17088              48403000                      -2.160100e+07
# 17098               7937000                       1.174000e+06
# 17104             -32012304                       0.000000e+00
# 17114               7494000                      -1.290000e+05
# 17126            5489000000                      -2.042000e+09
#
#        Income (Loss) from Continuing Operations  \
# 9                                     684000000
# 14                                    559000000
# 26                                   1919000000
# 33                                     -6969000
# 44                                    292536000
# ...                                         ...
# 17088                                  26802000
# 17098                                   9111000
# 17104                                 -32012304
# 17114                                   7365000
# 17126                                3447000000
#
#        Net Extraordinary Gains (Losses)  Net Income  Net Income (Common)
# 9                                   NaN   684000000            684000000
# 14                                  NaN   217000000            217000000
# 26                                  NaN  1919000000           1919000000
# 33                                  NaN    -6969000             -7175000
# 44                                  NaN   292536000            292536000
# ...                                 ...         ...                  ...
# 17088                               NaN    26802000             26802000
# 17098                               NaN     9111000              9111000
# 17104                               NaN   -32012304            -32012304
# 17114                               NaN     7365000              7365000
# 17126                               NaN  3447000000           3447000000
#
# [1780 rows x 28 columns]

# %%
# Separate out all reports from 2017 only
# And company with profit above $1000.
IsIt2017 = (Income_Data['Fiscal Year'] == 2017)
HasIncome = (Income_Data['Net Income'] >= 1000)
Income_Data[HasIncome & IsIt2017]
# Out:
#       Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 1          A     45846      USD         2017            FY  2017-10-31
# 8         AA    367153      USD         2017            FY  2017-12-31
# 14       AAL     68568      USD         2017            FY  2017-12-31
# 23       AAN    441241      USD         2017            FY  2017-12-31
# 28      AAOI    671827      USD         2017            FY  2017-12-31
# ...      ...       ...      ...          ...           ...         ...
# 10845   ZNGA    418866      USD         2017            FY  2017-12-31
# 10859    ZTS    378251      USD         2017            FY  2017-12-31
# 10864   ZUMZ     45730      USD         2017            FY  2018-01-31
# 10873    ZVO    901866      USD         2017            FY  2017-12-31
# 10884   ZYXI    171401      USD         2017            FY  2017-12-31
#
#       Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 1       2017-12-21    2018-12-20     322000000.0       326000000.0  ...
# 8       2018-02-26    2019-02-26     184000000.0       187000000.0  ...
# 14      2018-02-21    2019-02-25     489164000.0       491692000.0  ...
# 23      2018-03-01    2019-02-14      70837000.0        72121000.0  ...
# 28      2018-02-28    2018-02-28      19097355.0        20139105.0  ...
# ...            ...           ...             ...               ...  ...
# 10845   2018-02-20    2019-02-28     869067000.0       897165000.0  ...
# 10859   2018-02-15    2018-02-15     489918000.0       493161000.0  ...
# 10864   2018-03-19    2018-03-19      24679000.0        24878000.0  ...
# 10873   2018-02-21    2019-03-12      32058000.0        32794000.0  ...
# 10884   2018-02-28    2019-02-26      35371600.0        36515600.0  ...
#
#        Non-Operating Income (Loss)  Interest Expense, Net  \
# 1                      -38000000.0            -57000000.0
# 8                     -131000000.0           -104000000.0
# 14                    -836000000.0           -959000000.0
# 23                     -15122000.0            -18703000.0
# 28                      -2425000.0              -637000.0
# ...                            ...                    ...
# 10845                   11859000.0              5309000.0
# 10859                 -181000000.0           -175000000.0
# 10864                    -357000.0               495000.0
# 10873                    1511000.0                    NaN
# 10884                   -1450000.0             -1450000.0
#
#        Pretax Income (Loss), Adj.  Abnormal Gains (Losses)  \
# 1                       803000000                      NaN
# 8                      1468000000             -309000000.0
# 14                     3395000000                      NaN
# 23                      257571000              -17994000.0
# 28                       84526000                      NaN
# ...                           ...                      ...
# 10845                    37583000                      NaN
# 10859                  1544000000              -19000000.0
# 10864                    48403000                      NaN
# 10873                    16619000               -8682000.0
# 10884                     7494000                      NaN
#
#        Pretax Income (Loss)  Income Tax (Expense) Benefit, Net  \
# 1                 803000000                      -1.190000e+08
# 8                1159000000                      -6.000000e+08
# 14               3395000000                      -2.113000e+09
# 23                239577000                       5.295900e+07
# 28                 84526000                      -1.057500e+07
# ...                     ...                                ...
# 10845              37583000                      -1.094400e+07
# 10859            1525000000                      -6.630000e+08
# 10864              48403000                      -2.160100e+07
# 10873               7937000                       1.174000e+06
# 10884               7494000                      -1.290000e+05
#
#        Income (Loss) from Continuing Operations  \
# 1                                     684000000
# 8                                     559000000
# 14                                   1282000000
# 23                                    292536000
# 28                                     73951000
# ...                                         ...
# 10845                                  26639000
# 10859                                 862000000
# 10864                                  26802000
# 10873                                   9111000
# 10884                                   7365000
#
#        Net Extraordinary Gains (Losses)  Net Income  Net Income (Common)
# 1                                   NaN   684000000            684000000
# 8                                   NaN   217000000            217000000
# 14                                  NaN  1282000000           1282000000
# 23                                  NaN   292536000            292536000
# 28                                  NaN    73951000             73951000
# ...                                 ...         ...                  ...
# 10845                               NaN    26639000             26639000
# 10859                               NaN   864000000            864000000
# 10864                               NaN    26802000             26802000
# 10873                               NaN     9111000              9111000
# 10884                               NaN     7365000              7365000
#
# [1461 rows x 28 columns]

# %%
# Let's order the stocks for financial year 2017 by net income.
# Within a DataFrame the rows can be ordered as follows:
Income_Data.sort_values(by=['Net Income'])
# Out:
#       Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 6517      GE    244314      USD         2018            FY  2018-12-31
# 3769     COP    378120      USD         2008            FY  2008-12-31
# 14787   TEVA    616649      USD         2017            FY  2017-12-31
# 5761       F    249937      USD         2008            FY  2008-12-31
# 3261     CHK    378111      USD         2015            FY  2015-12-31
# ...      ...       ...      ...          ...           ...         ...
# 85      AAPL    111052      USD         2017            FY  2017-09-30
# 83      AAPL    111052      USD         2015            FY  2015-09-30
# 87      AAPL    111052      USD         2019            FY  2019-09-30
# 86      AAPL    111052      USD         2018            FY  2018-09-30
# 2520    BRKA     71306      USD         2019            FY  2019-12-31
#
#       Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 6517    2019-02-26    2019-02-26    8.691000e+09      8.691000e+09  ...
# 3769    2009-02-03    2011-02-23    1.523432e+09      1.523432e+09  ...
# 14787   2018-02-01    2019-02-19    1.016000e+09      1.016000e+09  ...
# 5761    2009-02-05    2011-02-28    2.273000e+09      2.272000e+09  ...
# 3261    2016-02-04    2018-02-22    3.310000e+06      3.310000e+06  ...
# ...            ...           ...             ...               ...  ...
# 85      2017-11-02    2018-11-05    5.217242e+09      5.251692e+09  ...
# 83      2015-10-28    2017-11-03    5.753421e+09      5.793069e+09  ...
# 87      2019-10-31    2019-10-31    4.617834e+09      4.648913e+09  ...
# 86      2018-11-05    2018-11-05    4.955377e+09      5.000109e+09  ...
# 2520    2020-02-24    2020-02-24    3.268661e+06      3.268661e+06  ...
#
#        Non-Operating Income (Loss)  Interest Expense, Net  \
# 6517                 -5.590000e+09          -5.059000e+09
# 3769                  4.263000e+09          -9.350000e+08
# 14787                 3.040000e+08          -8.950000e+08
# 5761                 -8.920000e+09          -9.737000e+09
# 3261                 -4.050000e+08          -3.170000e+08
# ...                            ...                    ...
# 85                    2.745000e+09                    NaN
# 83                    1.285000e+09                    NaN
# 87                    1.807000e+09                    NaN
# 86                    2.005000e+09                    NaN
# 2520                  4.187300e+10                    NaN
#
#        Pretax Income (Loss), Adj.  Abnormal Gains (Losses)  \
# 6517                   4779000000            -2.491300e+10
# 3769                  31409000000            -3.426900e+10
# 14787                  4295000000            -2.267400e+10
# 5761                 -14895000000                      NaN
# 3261                   -852000000            -1.824600e+10
# ...                           ...                      ...
# 85                    64089000000                      NaN
# 83                    72515000000                      NaN
# 87                    65737000000                      NaN
# 86                    72903000000                      NaN
# 2520                 101520000000                      NaN
#
#        Pretax Income (Loss)  Income Tax (Expense) Benefit, Net  \
# 6517           -20134000000                      -5.830000e+08
# 3769            -2860000000                      -1.341900e+10
# 14787          -18379000000                       1.933000e+09
# 5761           -14895000000                       6.200000e+07
# 3261           -19098000000                       4.463000e+09
# ...                     ...                                ...
# 85              64089000000                      -1.573800e+10
# 83              72515000000                      -1.912100e+10
# 87              65737000000                      -1.048100e+10
# 86              72903000000                      -1.337200e+10
# 2520           101520000000                      -2.090400e+10
#
#        Income (Loss) from Continuing Operations  \
# 6517                               -20717000000
# 3769                               -16279000000
# 14787                              -16449000000
# 5761                               -14833000000
# 3261                               -14635000000
# ...                                         ...
# 85                                  48351000000
# 83                                  53394000000
# 87                                  55256000000
# 86                                  59531000000
# 2520                                81792000000
#
#        Net Extraordinary Gains (Losses)   Net Income  Net Income (Common)
# 6517                      -1.726000e+09 -22354000000         -22801000000
# 3769                                NaN -16349000000         -16349000000
# 14787                               NaN -16265000000         -16525000000
# 5761                       9.000000e+06 -14766000000         -14766000000
# 3261                                NaN -14567000000         -14738000000
# ...                                 ...          ...                  ...
# 85                                  NaN  48351000000          48351000000
# 83                                  NaN  53394000000          53394000000
# 87                                  NaN  55256000000          55256000000
# 86                                  NaN  59531000000          59531000000
# 2520                                NaN  81417000000          81417000000
#
# [17129 rows x 28 columns]

# %%
# However, we wish to perform this for only the 2017 fiscal year. 
# Fortunately you can just put one operations in front of the other as follows:
Income_Data[Income_Data['Fiscal Year'] == 2020].sort_values(by=['Net Income'])
# It looks like AAPL and BRKA earned the most money that year, more than $40bn!
# Out:
#       Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 70      ABEO    953884      USD         2020            FY  2020-12-31
# 10713    XOM    121214      USD         2020            FY  2020-12-31
# 1294     BHI     71832      USD         2020            FY  2020-12-31
# 7300     OXY    334205      USD         2020            FY  2020-12-31
# 2755     DAL    231789      USD         2020            FY  2020-12-31
# ...      ...       ...      ...          ...           ...         ...
# 3637      FB    121021      USD         2020            FY  2020-12-31
# 4244    GOOG        18      USD         2020            FY  2020-12-31
# 1517   BRK-A     71306      USD         2020            FY  2020-12-31
# 6442    MSFT     59265      USD         2020            FY  2020-06-30
# 46      AAPL    111052      USD         2020            FY  2020-09-30
#
#       Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 70      2021-03-24    2022-03-31    9.266357e+07      9.266357e+07  ...
# 10713   2021-02-24    2022-02-23    4.271000e+09      4.271000e+09  ...
# 1294    2021-02-25    2022-02-11    4.290000e+08      4.340000e+08  ...
# 7300    2021-02-26    2022-02-24    9.187000e+08      9.187000e+08  ...
# 2755    2021-02-12    2022-02-11    6.360000e+08      6.360000e+08  ...
# ...            ...           ...             ...               ...  ...
# 3637    2021-01-28    2022-02-03    2.851000e+09      2.888000e+09  ...
# 4244    2021-02-03    2022-02-02    6.808160e+08      7.332100e+08  ...
# 1517    2021-03-01    2022-02-28    3.188892e+06      3.188892e+06  ...
# 6442    2020-07-30    2021-07-29    7.610000e+09      7.683000e+09  ...
# 46      2020-10-30    2021-10-29    1.735212e+10      1.752821e+10  ...
#
#        Non-Operating Income (Loss)  Interest Expense, Net  \
# 70                   -2.814000e+09          -2.814000e+09
# 10713                -2.554800e+10          -1.158000e+09
# 1294                  7.760000e+08          -2.640000e+08
# 7300                 -1.054000e+09          -1.424000e+09
# 2755                 -5.730000e+08          -9.290000e+08
# ...                            ...                    ...
# 3637                  5.090000e+08                    NaN
# 4244                  6.858000e+09                    NaN
# 1517                  3.667600e+10                    NaN
# 6442                  7.700000e+07                    NaN
# 46                    8.030000e+08                    NaN
#
#        Pretax Income (Loss), Adj.  Abnormal Gains (Losses)  \
# 70                   -51318000000            -3.291600e+10
# 10713                -28883000000                      NaN
# 1294                   1571000000            -1.671700e+10
# 7300                  -2465000000            -1.324000e+10
# 2755                  -8769000000            -6.818000e+09
# ...                           ...                      ...
# 3637                  33180000000                      NaN
# 4244                  48082000000             0.000000e+00
# 1517                  66364000000            -1.067100e+10
# 6442                  53036000000                      NaN
# 46                    67091000000                      NaN
#
#        Pretax Income (Loss)  Income Tax (Expense) Benefit, Net  \
# 70             -84234000000                                NaN
# 10713          -28883000000                       5.632000e+09
# 1294           -15146000000                      -6.500000e+08
# 7300           -15705000000                       2.172000e+09
# 2755           -15587000000                       3.202000e+09
# ...                     ...                                ...
# 3637            33180000000                      -4.034000e+09
# 4244            48082000000                      -7.813000e+09
# 1517            55693000000                      -1.244000e+10
# 6442            53036000000                      -8.755000e+09
# 46              67091000000                      -9.680000e+09
#
#        Income (Loss) from Continuing Operations  \
# 70                                 -84234000000
# 10713                              -23251000000
# 1294                               -15796000000
# 7300                               -13533000000
# 2755                               -12385000000
# ...                                         ...
# 3637                                29146000000
# 4244                                40269000000
# 1517                                43253000000
# 6442                                44281000000
# 46                                  57411000000
#
#        Net Extraordinary Gains (Losses)   Net Income  Net Income (Common)
# 70                                  NaN -84234000000         -84234000000
# 10713                               NaN -22440000000         -22440000000
# 1294                                NaN -15825000000         -15825000000
# 7300                      -1.298000e+09 -14831000000         -15675000000
# 2755                                NaN -12385000000         -12385000000
# ...                                 ...          ...                  ...
# 3637                                NaN  29146000000          29146000000
# 4244                                NaN  40269000000          40269000000
# 1517                                NaN  42521000000          42521000000
# 6442                                NaN  44281000000          44281000000
# 46                                  NaN  57411000000          57411000000
#
# [2149 rows x 28 columns]

# %%
# Lets plot the distribution of net income for all american companies:
Income_Data['Net Income'].hist()

# %%
# Plot graph with just 2020 FY data, logarithmic Y axis and more bins for greater resolution.
from matplotlib import pyplot as plt # Import plotting library

# Boolean mask for year 2020 data only.
Year2020Only = (Income_Data['Fiscal Year'] == 2020)

# Boolean mask for Companies with greater than -$10Bn profit
reasonableProfit = (Income_Data['Net Income'] >= -1e10)

# Use the booklean masks and plot the data
Income_Data[Year2020Only&reasonableProfit]['Net Income'].hist(bins=100, 
                                                              log=True)
plt.title('USA Corporate Net Income for 2020 Histogram')
plt.xlabel('Value in USD')
plt.ylabel('Number of Instances')

print('Max profit value was: $', Income_Data[Year2020Only&reasonableProfit]['Net Income'].max()/1e9,'Billion')
# Out:
# Max profit value was: $ 57.411 Billion

# %%
# Find the top 10 USA companies by net income, 2020.
Income_Data[Year2020Only&reasonableProfit][['Ticker',
                                            'Currency',
                                            'Fiscal Year', 
                                            'Report Date',
                                            'Publish Date',
                                            'Restated Date',
                                            'Net Income']].sort_values(by=['Net Income'], ascending=False).head(10)
# Out:
#       Ticker Currency  Fiscal Year Report Date Publish Date Restated Date  \
# 46      AAPL      USD         2020  2020-09-30   2020-10-30    2021-10-29
# 6442    MSFT      USD         2020  2020-06-30   2020-07-30    2021-07-29
# 1517   BRK-A      USD         2020  2020-12-31   2021-03-01    2022-02-28
# 4244    GOOG      USD         2020  2020-12-31   2021-02-03    2022-02-02
# 3637      FB      USD         2020  2020-12-31   2021-01-28    2022-02-03
# 660     AMZN      USD         2020  2020-12-31   2021-02-03    2022-02-04
# 9502      TM      USD         2020  2021-03-31   2021-06-24    2021-06-24
# 4935    INTC      USD         2020  2020-12-31   2021-01-22    2022-01-27
# 10344     VZ      USD         2020  2020-12-31   2021-02-25    2022-02-11
# 9953     UNH      USD         2020  2020-12-31   2021-03-01    2022-02-15
#
#         Net Income
# 46     57411000000
# 6442   44281000000
# 1517   42521000000
# 4244   40269000000
# 3637   29146000000
# 660    21331000000
# 9502   21172891845
# 4935   20899000000
# 10344  17801000000
# 9953   15403000000

# %%
# Statistical data can be calculated with the dataframe .describe() function
Income_Data.describe()
# Out:
#             SimFinId   Fiscal Year  Shares (Basic)  Shares (Diluted)  \
# count   17129.000000  17129.000000    1.701800e+04      1.701800e+04
# mean   413064.400782   2014.407905    2.354918e+08      2.398169e+08
# std    275023.871212      3.022925    6.509797e+08      6.650934e+08
# min        18.000000   2007.000000    3.700000e+01      3.700000e+01
# 25%    169714.000000   2012.000000    2.696775e+07      2.731600e+07
# 50%    378111.000000   2015.000000    6.620768e+07      6.732950e+07
# 75%    652365.000000   2017.000000    1.886207e+08      1.914318e+08
# max    993675.000000   2020.000000    1.066100e+10      1.067800e+10
#
#             Revenue  Cost of Revenue  Gross Profit  Operating Expenses  \
# count  1.684100e+04     1.557400e+04  1.685600e+04        1.704900e+04
# mean   7.481832e+09    -5.224883e+09  2.648404e+09       -1.681331e+09
# std    2.469681e+10     1.877478e+10  8.084087e+09        5.050896e+09
# min    0.000000e+00    -3.946050e+11 -1.280800e+10       -1.087910e+11
# 25%    2.839920e+08    -3.100996e+09  1.200918e+08       -1.225803e+09
# 50%    1.425395e+09    -7.958500e+08  5.702680e+08       -3.675850e+08
# 75%    5.190000e+09    -1.457800e+08  1.970400e+09       -9.270000e+07
# max    5.239640e+11     3.100000e+07  1.722200e+11        1.110132e+09
#
#        Selling, General & Administrative  Research & Development  ...  \
# count                       1.628600e+04            6.812000e+03  ...
# mean                       -1.143160e+09           -4.013717e+08  ...
# std                         4.025915e+09            1.323563e+09  ...
# min                        -1.087910e+11           -2.601800e+10  ...
# 25%                        -8.088830e+08           -1.892340e+08  ...
# 50%                        -2.115150e+08           -5.372050e+07  ...
# 75%                        -4.799025e+07           -1.443925e+07  ...
# max                         0.000000e+00            6.480000e+05  ...
#
#        Non-Operating Income (Loss)  Interest Expense, Net  \
# count                 1.697800e+04           1.514400e+04
# mean                 -1.232958e+08          -1.348186e+08
# std                   1.346241e+09           4.793649e+08
# min                  -5.912000e+10          -2.575800e+10
# 25%                  -8.533300e+07          -1.110358e+08
# 50%                  -1.110000e+07          -2.268100e+07
# 75%                  -4.100000e+04          -9.127698e+05
# max                   4.187300e+10           1.537000e+09
#
#        Pretax Income (Loss), Adj.  Abnormal Gains (Losses)  \
# count                1.712900e+04             1.133900e+04
# mean                 8.109714e+08            -1.352606e+08
# std                  3.204352e+09             9.846223e+08
# min                 -1.489500e+10            -3.426900e+10
# 25%                  8.650000e+05            -4.500000e+07
# 50%                  1.003120e+08            -4.471000e+06
# 75%                  5.156530e+08             0.000000e+00
# max                  1.015200e+11             1.289400e+10
#
#        Pretax Income (Loss)  Income Tax (Expense) Benefit, Net  \
# count          1.712900e+04                       1.613200e+04
# mean           7.214320e+08                      -1.967143e+08
# std            3.202980e+09                       1.097688e+09
# min           -2.869500e+10                      -3.653000e+10
# 25%           -1.315979e+06                      -1.261730e+08
# 50%            8.128300e+07                      -2.055800e+07
# 75%            4.680000e+08                      -3.170000e+05
# max            1.015200e+11                       3.483100e+10
#
#        Income (Loss) from Continuing Operations  \
# count                              1.712900e+04
# mean                               5.383015e+08
# std                                2.416212e+09
# min                               -2.071700e+10
# 25%                               -1.579000e+06
# 50%                                6.057800e+07
# 75%                                3.538230e+08
# max                                8.179200e+10
#
#        Net Extraordinary Gains (Losses)    Net Income  Net Income (Common)
# count                      3.655000e+03  1.712900e+04         1.712900e+04
# mean                       4.870889e+07  5.323545e+08         5.295753e+08
# std                        6.350838e+08  2.406332e+09         2.405082e+09
# min                       -9.559000e+09 -2.235400e+10        -2.280100e+10
# 25%                       -3.792500e+06 -1.705000e+06        -2.018000e+06
# 50%                        0.000000e+00  5.896400e+07         5.820800e+07
# 75%                        1.454000e+07  3.527900e+08         3.501040e+08
# max                        1.591450e+10  8.141700e+10         8.141700e+10
#
# [8 rows x 22 columns]

# %%
# You can create new dataframes from filtered old dataframes.
# Let's separate the 2017 fiscal year data to a new dataframe.
Income_Data_2020 = Income_Data[Income_Data['Fiscal Year'] == 2020]

# %%
Income_Data_2020.head(9)
# Out:
#    Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 4       A     45846      USD         2020            FY  2020-10-31
# 6     A21   1333027      USD         2020            FY  2020-12-31
# 11     AA    367153      USD         2020            FY  2020-12-31
# 17    AAL     68568      USD         2020            FY  2020-12-31
# 26    AAN    441241      USD         2020            FY  2020-12-31
# 31   AAOI    671827      USD         2020            FY  2020-12-31
# 36   AAON    919501      USD         2020            FY  2020-12-31
# 41    AAP    184955      USD         2020            FY  2020-12-31
# 46   AAPL    111052      USD         2020            FY  2020-09-30
#
#    Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 4    2020-12-18    2021-12-17    3.090000e+08      3.120000e+08  ...
# 6    2021-03-10    2022-04-19             NaN               NaN  ...
# 11   2021-02-25    2022-02-24    1.860000e+08      1.860000e+08  ...
# 17   2021-02-17    2022-02-22    4.838880e+08      4.838880e+08  ...
# 26   2021-01-26    2022-02-24    3.387700e+07      3.387700e+07  ...
# 31   2021-02-25    2022-02-24    2.186663e+07      2.186663e+07  ...
# 36   2021-02-25    2022-02-28    5.216868e+07      5.306117e+07  ...
# 41   2021-02-22    2022-02-15    6.874800e+07      6.900300e+07  ...
# 46   2020-10-30    2021-10-29    1.735212e+10      1.752821e+10  ...
#
#     Non-Operating Income (Loss)  Interest Expense, Net  \
# 4                 -4.000000e+06          -7.000000e+07
# 6                  2.081330e+08           1.880000e+08
# 11                -1.540000e+08          -1.460000e+08
# 17                -1.032000e+09          -1.186000e+09
# 26                -7.697000e+06          -1.000600e+07
# 31                -2.382000e+06          -5.380000e+06
# 36                 1.390000e+05           8.800000e+04
# 41                -5.087000e+07          -4.688600e+07
# 46                 8.030000e+08                    NaN
#
#     Pretax Income (Loss), Adj.  Abnormal Gains (Losses)  Pretax Income (Loss)  \
# 4                    842000000                      NaN             842000000
# 6                   -461204000              272327000.0            -188877000
# 11                   277000000             -104000000.0             173000000
# 17                -11453000000                      NaN          -11453000000
# 26                   167528000             -565342000.0            -397814000
# 31                   -51224000                      NaN             -51224000
# 36                    95497000                6478000.0             101975000
# 41                   699037000              -48022000.0             651015000
# 46                 67091000000                      NaN           67091000000
#
#     Income Tax (Expense) Benefit, Net  \
# 4                       -1.230000e+08
# 6                        2.284700e+07
# 11                      -1.870000e+08
# 17                       2.568000e+09
# 26                       1.319020e+08
# 31                      -7.228000e+06
# 36                      -2.296600e+07
# 41                      -1.579940e+08
# 46                      -9.680000e+09
#
#     Income (Loss) from Continuing Operations  \
# 4                                  719000000
# 6                                 -166030000
# 11                                 -14000000
# 17                               -8885000000
# 26                                -265912000
# 31                                 -58452000
# 36                                  79009000
# 41                                 493021000
# 46                               57411000000
#
#     Net Extraordinary Gains (Losses)   Net Income  Net Income (Common)
# 4                                NaN    719000000            719000000
# 6                                NaN   -140795000           -791985000
# 11                               NaN   -170000000           -170000000
# 17                               NaN  -8885000000          -8885000000
# 26                               NaN   -265912000           -265912000
# 31                               NaN    -58452000            -58452000
# 36                               NaN     79009000             79009000
# 41                               NaN    493021000            493021000
# 46                               NaN  57411000000          57411000000
#
# [9 rows x 28 columns]

# %%
Income_Data_2017.tail()
# Out:
#       Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 17088   ZUMZ     45730      USD         2017            FY  2018-02-28
# 17098    ZVO    901866      USD         2017            FY  2017-12-31
# 17104   ZYNE    901704      USD         2017            FY  2017-12-31
# 17114   ZYXI    171401      USD         2017            FY  2017-12-31
# 17126    low    186050      USD         2017            FY  2018-02-28
#
#       Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 17088   2018-03-19    2018-03-19      24679000.0        24878000.0  ...
# 17098   2018-02-21    2019-03-12      32058000.0        32794000.0  ...
# 17104   2018-03-12    2019-03-11      12914814.0        12914814.0  ...
# 17114   2018-02-28    2018-02-28      32156000.0        33196000.0  ...
# 17126   2018-04-02    2018-04-02     839000000.0       840000000.0  ...
#
#        Non-Operating Income (Loss)  Interest Expense, Net  \
# 17088                    -357000.0               495000.0
# 17098                    1511000.0                    NaN
# 17104                     810705.0               519554.0
# 17114                   -1450000.0             -1450000.0
# 17126                 -633000000.0           -633000000.0
#
#        Pretax Income (Loss), Adj.  Abnormal Gains (Losses)  \
# 17088                    48403000                      NaN
# 17098                    16619000               -8682000.0
# 17104                   -32012304                      0.0
# 17114                     7494000                      NaN
# 17126                  5953000000             -464000000.0
#
#        Pretax Income (Loss)  Income Tax (Expense) Benefit, Net  \
# 17088              48403000                      -2.160100e+07
# 17098               7937000                       1.174000e+06
# 17104             -32012304                       0.000000e+00
# 17114               7494000                      -1.290000e+05
# 17126            5489000000                      -2.042000e+09
#
#        Income (Loss) from Continuing Operations  \
# 17088                                  26802000
# 17098                                   9111000
# 17104                                 -32012304
# 17114                                   7365000
# 17126                                3447000000
#
#        Net Extraordinary Gains (Losses)  Net Income  Net Income (Common)
# 17088                               NaN    26802000             26802000
# 17098                               NaN     9111000              9111000
# 17104                               NaN   -32012304            -32012304
# 17114                               NaN     7365000              7365000
# 17126                               NaN  3447000000           3447000000
#
# [5 rows x 28 columns]

# %% [markdown]
# # Exercise 6 - Fix The Code

# %%
import pandas as pd

# If stored the files in a different location
#incomeDataFile = 'C:/Users/G50/Stock_Data/SimFin/us-income-annual/us-income-annual.csv'
#stockPricesFile = 'C:/Users/G50/Stock_Data/SimFin/us-shareprices-daily/us-shareprices-daily.csv'

# If files in current directory
incomeDataFile = 'us-income-annual.csv'
stockPricesFile = 'us-shareprices-daily.csv'

Income_Data = pd.read_csv(incomeDataFile, 
                          delimiter=';')

stock_prices = pd.read_csv(stockPricesFile, 
                           delimiter=???)

# %% [markdown]
# ## Preliminary View Of The Data

# %%
# How big are these dataframes? How is the data stored? 
print('Income data size is: ', Income_Data.shape)
print('stock_prices data size is: ', stock_prices.???)
# Out:
# Income data size is:  (10888, 28)
# stock_prices data size is:  (3131472, 11)

# %%
# What does the data look like? Use head() to take a look.
Income_Data.head(5) # See income statement data sample
# Out:
#   Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 0      A     45846      USD         2016            FY  2016-10-31
# 1      A     45846      USD         2017            FY  2017-10-31
# 2      A     45846      USD         2018            FY  2018-10-31
# 3      A     45846      USD         2019            FY  2019-10-31
# 4      A     45846      USD         2020            FY  2020-10-31
#
#   Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 0   2016-12-20    2018-12-20     326000000.0       329000000.0  ...
# 1   2017-12-21    2018-12-20     322000000.0       326000000.0  ...
# 2   2018-12-20    2020-12-18     321000000.0       325000000.0  ...
# 3   2019-12-19    2021-12-17     314000000.0       318000000.0  ...
# 4   2020-12-18    2021-12-17     309000000.0       312000000.0  ...
#
#    Non-Operating Income (Loss)  Interest Expense, Net  \
# 0                  -71000000.0            -61000000.0
# 1                  -38000000.0            -57000000.0
# 2                   42000000.0            -37000000.0
# 3                  -22000000.0            -38000000.0
# 4                   -4000000.0            -70000000.0
#
#    Pretax Income (Loss), Adj.  Abnormal Gains (Losses)  Pretax Income (Loss)  \
# 0                   544000000                      NaN             544000000
# 1                   803000000                      NaN             803000000
# 2                   946000000                      NaN             946000000
# 3                   919000000                      NaN             919000000
# 4                   842000000                      NaN             842000000
#
#    Income Tax (Expense) Benefit, Net  \
# 0                        -82000000.0
# 1                       -119000000.0
# 2                       -630000000.0
# 3                        152000000.0
# 4                       -123000000.0
#
#    Income (Loss) from Continuing Operations  Net Extraordinary Gains (Losses)  \
# 0                                 462000000                               NaN
# 1                                 684000000                               NaN
# 2                                 316000000                               NaN
# 3                                1071000000                               NaN
# 4                                 719000000                               NaN
#
#    Net Income  Net Income (Common)
# 0   462000000            462000000
# 1   684000000            684000000
# 2   316000000            316000000
# 3  1071000000           1071000000
# 4   719000000            719000000
#
# [5 rows x 28 columns]

# %%
stock_prices.???(5) # See stock price data sample
# Out:
#   Ticker  SimFinId        Date    Open     Low    High   Close  Adj. Close  \
# 0   GOOG        18  2016-05-04  690.49  689.01  699.75  695.70      695.70
# 1   GOOG        18  2016-05-05  697.70  695.72  702.32  701.43      701.43
# 2   GOOG        18  2016-05-06  698.38  698.11  711.86  711.12      711.12
# 3   GOOG        18  2016-05-09  712.00  710.00  718.71  712.90      712.90
# 4   GOOG        18  2016-05-10  716.75  715.72  723.50  723.18      723.18
#
#    Dividend   Volume  Shares Outstanding
# 0       NaN  1693525         686555233.0
# 1       NaN  1683507         686555233.0
# 2       NaN  1829291         686555233.0
# 3       NaN  1510289         686555233.0
# 4       NaN  1569591         686555233.0

# %%
Income_Data.describe() # See some statistics about income statement data.
# Out:
#            SimFinId   Fiscal Year  Shares (Basic)  Shares (Diluted)  \
# count  1.088800e+04  10888.000000    1.081500e+04      1.081500e+04
# mean   5.663473e+05   2018.005051    2.019112e+08      2.047898e+08
# std    3.701861e+05      1.415081    6.601202e+08      6.668838e+08
# min    1.800000e+01   2016.000000    5.400000e+01      5.400000e+01
# 25%    2.317890e+05   2017.000000    2.763523e+07      2.796215e+07
# 50%    5.202940e+05   2018.000000    6.192700e+07      6.290000e+07
# 75%    8.904600e+05   2019.000000    1.580160e+08      1.602862e+08
# max    1.342109e+06   2021.000000    2.188328e+10      2.200112e+10
#
#             Revenue  Cost of Revenue  Gross Profit  Operating Expenses  \
# count  1.059600e+04     9.771000e+03  9.764000e+03        1.087500e+04
# mean   6.515999e+09    -4.550891e+09  2.384089e+09       -1.538194e+09
# std    2.335750e+10     1.807518e+10  7.723733e+09        5.125159e+09
# min   -9.323700e+07    -4.203150e+11 -5.685000e+09       -1.298580e+11
# 25%    2.590885e+08    -2.544530e+09  1.343305e+08       -1.056030e+09
# 50%    1.223112e+09    -6.910830e+08  5.393810e+08       -3.420000e+08
# 75%    4.244555e+09    -1.276525e+08  1.640308e+09       -9.588450e+07
# max    5.591510e+11     1.382000e+06  1.527570e+11       -1.000000e+03
#
#        Selling, General & Administrative  Research & Development  ...  \
# count                       1.036200e+04            4.654000e+03  ...
# mean                       -9.772376e+08           -3.718172e+08  ...
# std                         3.639178e+09            1.515478e+09  ...
# min                        -1.162880e+11           -3.013900e+10  ...
# 25%                        -6.519862e+08           -1.607548e+08  ...
# 50%                        -1.902995e+08           -5.470650e+07  ...
# 75%                        -4.584020e+07           -1.561300e+07  ...
# max                         0.000000e+00            6.480000e+05  ...
#
#        Non-Operating Income (Loss)  Interest Expense, Net  \
# count                 1.081200e+04           9.751000e+03
# mean                 -9.895091e+07          -1.278607e+08
# std                   1.129606e+09           3.639966e+08
# min                  -4.264700e+10          -8.422000e+09
# 25%                  -8.402500e+07          -1.094275e+08
# 50%                  -1.196450e+07          -2.312800e+07
# 75%                  -1.500000e+04          -1.228190e+06
# max                   6.978100e+10           3.655951e+09
#
#        Pretax Income (Loss), Adj.  Abnormal Gains (Losses)  \
# count                1.088800e+04             6.882000e+03
# mean                 6.233367e+08            -1.534800e+08
# std                  3.027103e+09             1.068937e+09
# min                 -5.131800e+10            -3.291600e+10
# 25%                 -1.001225e+07            -6.070000e+07
# 50%                  5.641950e+07            -7.700000e+06
# 75%                  3.745595e+08             0.000000e+00
# max                  1.027920e+11             1.289400e+10
#
#        Pretax Income (Loss)  Income Tax (Expense) Benefit, Net  \
# count          1.088800e+04                       9.946000e+03
# mean           5.263263e+08                      -1.221122e+08
# std            3.101587e+09                       8.547407e+08
# min           -8.423400e+10                      -2.090400e+10
# 25%           -1.939375e+07                      -7.600000e+07
# 50%            4.100000e+07                      -8.697050e+06
# 75%            3.399272e+08                       0.000000e+00
# max            1.026960e+11                       2.151500e+10
#
#        Income (Loss) from Continuing Operations  \
# count                              1.088800e+04
# mean                               4.166901e+08
# std                                2.619621e+09
# min                               -8.423400e+10
# 25%                               -1.945700e+07
# 50%                                3.193450e+07
# 75%                                2.688062e+08
# max                                8.179200e+10
#
#        Net Extraordinary Gains (Losses)    Net Income  Net Income (Common)
# count                      1.551000e+03  1.088800e+04         1.088800e+04
# mean                       7.919118e+07  4.170507e+08         4.144405e+08
# std                        7.488039e+08  2.624205e+09         2.625029e+09
# min                       -4.893000e+09 -8.423400e+10        -8.423400e+10
# 25%                       -4.867000e+06 -1.995025e+07        -2.109850e+07
# 50%                        0.000000e+00  3.097400e+07         2.984715e+07
# 75%                        1.905000e+07  2.644742e+08         2.638130e+08
# max                        1.591450e+10  8.141700e+10         8.141700e+10
#
# [8 rows x 22 columns]

# %%
stock_prices.??? # See some statistics about stock price data.
# Out:
#            SimFinId          Open           Low          High         Close  \
# count  3.131472e+06  3.110358e+06  3.109921e+06  3.110771e+06  3.110387e+06
# mean   5.831554e+05  1.895114e+02  1.870060e+02  1.916967e+02  1.892637e+02
# std    3.698268e+05  6.082513e+03  6.025263e+03  6.131234e+03  6.076621e+03
# min    1.800000e+01  1.000000e-02  1.000000e-02  1.000000e-02  1.000000e-02
# 25%    2.495020e+05  1.215000e+01  1.188000e+01  1.241000e+01  1.214000e+01
# 50%    5.454890e+05  3.000000e+01  2.951000e+01  3.048000e+01  3.000000e+01
# 75%    9.056720e+05  6.392000e+01  6.303000e+01  6.476000e+01  6.390000e+01
# max    1.348020e+06  4.190950e+05  4.172720e+05  4.226478e+05  4.214200e+05
#
#          Adj. Close      Dividend        Volume  Shares Outstanding
# count  3.110589e+06  23521.000000  3.131472e+06        3.087969e+06
# mean   1.868756e+02      0.426164  1.975702e+06        2.533493e+08
# std    6.076450e+03      1.553895  1.147495e+07        3.382952e+09
# min    1.000000e-02      0.000000  0.000000e+00        9.000000e+00
# 25%    1.131000e+01      0.130000  1.315828e+05        2.855143e+07
# 50%    2.798000e+01      0.250000  4.932410e+05        6.557298e+07
# 75%    5.999000e+01      0.460000  1.502449e+06        1.671934e+08
# max    4.214200e+05    103.750000  3.996180e+09        4.157000e+11

# %%
'''
We can understand a lot about the stock market with this data with some plots
Feel free to try different plots

Here I'm plotting the SG&A expense vs. the gross profit. 
We expect some kind of relationship between these.
'''

Income_Data.plot.scatter(x = 'Selling, General & Administrative', y = 'Gross Profit')
plt.grid()

# %% [markdown]
# ## Exploring Some Companies From The Data

# %%
'''
Notice int he last plot that there is one company with a crazy high gross profit, 
yet having a very low SG&A spend, relatively speaking.

Any guesses for which company this is? And what year? Let's find out.
'''

Income_Data[['Ticker',
            'Currency',
            'Fiscal Year', 
            'Report Date',
            'Publish Date',
            'Restated Date',
            'Net Income',
            'Selling, General & Administrative',
            'Gross Profit']].sort_values(by='Gross Profit', ascending=False).head(???)
# Out:
#       Ticker Currency  Fiscal Year Report Date Publish Date Restated Date  \
# 660     AMZN      USD         2020  2020-12-31   2021-02-03    2022-02-04
# 10536    WMT      USD         2020  2021-01-31   2021-03-19    2022-03-18
# 10535    WMT      USD         2019  2020-01-31   2020-03-20    2022-03-18
# 10534    WMT      USD         2018  2019-01-31   2019-03-28    2021-03-19
# 10533    WMT      USD         2017  2018-01-31   2018-03-30    2018-03-30
# 10532    WMT      USD         2016  2017-01-31   2017-03-31    2018-03-30
# 659     AMZN      USD         2019  2019-12-31   2020-01-31    2022-02-04
# 46      AAPL      USD         2020  2020-09-30   2020-10-30    2021-10-29
# 44      AAPL      USD         2018  2018-09-30   2018-11-05    2020-10-30
# 45      AAPL      USD         2019  2019-09-30   2019-10-31    2021-10-29
#
#         Net Income  Selling, General & Administrative  Gross Profit
# 660    21331000000                      -2.867600e+10  1.527570e+11
# 10536  13510000000                      -1.162880e+11  1.388360e+11
# 10535  14881000000                      -1.087910e+11  1.293590e+11
# 10534   6670000000                      -1.071470e+11  1.291040e+11
# 10533   9862000000                      -1.065100e+11  1.269470e+11
# 10532  13643000000                      -1.018530e+11  1.246170e+11
# 659    11588000000                      -2.408100e+10  1.149860e+11
# 46     57411000000                      -1.991600e+10  1.049560e+11
# 44     59531000000                      -1.670500e+10  1.018390e+11
# 45     55256000000                      -1.824500e+10  9.839200e+10

# %%
# Not really surprising that it's Amazon, and that the top 10 includes Wall Mart and Apple.

# %%
# Let's take a look at some data from AMZN by itelf.
Income_Data[Income_Data['Ticker']=='AMZN']['Revenue']
# Out:
# 656    1.359870e+11
# 657    1.778660e+11
# 658    2.328870e+11
# 659    2.805220e+11
# 660    3.860640e+11
# Name: Revenue, dtype: float64

# %%
# We can plot this data and see how the revenue and income changed over time.
# Amazon seems to grow revenues steadily, but the income grows much faster proportionally.
# Documentation for bar charts is here: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.bar.html

Income_Data[Income_Data['Ticker']=='?????'].plot.bar(x='Report Date', 
                                                    y=['Revenue',
                                                       'Net Income'], 
                                                    rot=0, 
                                                    subplots=True,
                                                    grid='on',
                                                    title='Amazon Revenue and Net Income');

# %%
# Let's try a slow growth company, Wall Mart.
Income_Data[Income_Data['Ticker']=='WMT'].plot.bar(x='Report Date', 
                                                    y=['Revenue',
                                                       'Net Income'], 
                                                    rot=0, 
                                                    subplots=True,
                                                    grid='on',
                                                    title='Wall Mart Revenue and Net Income');

# %% [markdown]
# ## Working Out A Market Capitalisation Figure Manually

# %%
'''
In fundamentals investing, you'll want an idea of the valuation of a company
relative to something else, e.g. the earnings, or the value of the assets.
This would be reflected in ratios like the Price/Earnings ratio, etc.
This requires a Market Cap figure, which we don't have currently.

We'll work out a market cap figure here manually, in the process trying out some pandas functions.

We'll do this for 2020 only, and to do it we will take the number of shares outstanding,
and multiply this by the share price at the time.

Bear in mind that the share prices and number of shares outstanding change over time,
so this market cap figure and any ratios derived from it will be rough numbers.

Another limitation is that there might not be a stock price reported for that specific day
and we aren't finding the closest days price to use at this point (we will do later).
''';

# %%
# Get the date format set correctly.
Income_Data['Publish Date']=pd.to_datetime(Income_Data['Publish Date'])

# Plot a histogram with a large number of bins to get an idea of when most reporting is done.
Income_Data[Income_Data['Fiscal Year'] == 2019]['Publish Date'].hist(bins=100);
plt.title('USA stocks Annual Report Publish Date\n For Fiscal Year 2019\n'+
          str(len(Income_Data[Income_Data['Fiscal Year'] == 2019]['Ticker'].unique()))+
          ' Stocks In Total');
plt.xlabel('Publish Date');
plt.ylabel('Number of Instances');

# %%
# Make a new dataframe of only the income data from 'Fiscal Year' == 2019.
Income_Data_2019 = Income_Data[Income_Data['Fiscal Year'] == ???]

# View the series of company tickers that exist for that fiscal year.
(Income_Data[Income_Data['Fiscal Year'] == ???]['Ticker']).unique
# Out:
# <bound method Series.unique of 3           A
# 5         A21
# 10         AA
# 16        AAL
# 21       AAMC
#          ...
# 10866    ZUMZ
# 10870     ZUO
# 10875     ZVO
# 10881    ZYNE
# 10886    ZYXI
# Name: Ticker, Length: 2170, dtype: object>

# %%
# It appears as though most reporting is done just after the beginning of March for these companies.
# We need stock prices that correspond to that date (roughly).
# Filter the stock price dataframe for the beginning of March.
stock_prices_2019 = (stock_prices[stock_prices['Date'] == '2020-03-02'])
print('stock_prices_2019 dataframe shape is: ', stock_prices_2019.shape)
stock_prices_2019.head(10)
# Out:
# stock_prices_2019 dataframe shape is:  (2475, 11)
#         Ticker  SimFinId        Date     Open      Low     High    Close  \
# 962       GOOG        18  2020-03-02  1351.61  1326.82  1390.87  1389.11
# 1503   FOX_old       242  2020-03-02    30.48    30.07    31.79    31.79
# 2762      ATVI       243  2020-03-02    58.30    57.91    60.65    60.59
# 4021       BLK       914  2020-03-02   467.14   461.57   488.18   487.94
# 5280      ADBE     14099  2020-03-02   349.81   342.61   360.75   360.28
# 6539       MMM     22219  2020-03-02   151.34   148.37   153.43   153.02
# 7798       PPL     26853  2020-03-02    30.31    30.22    31.83    31.81
# 9057      TWTR     30388  2020-03-02    36.00    35.14    36.86    35.82
# 10316     BRID     33021  2020-03-02    17.52    17.25    18.68    18.68
# 11575      NWY     33184  2020-03-02     0.28     0.27     0.32     0.31
#
#        Adj. Close  Dividend    Volume  Shares Outstanding
# 962       1389.11       NaN   2431468        6.872861e+08
# 1503        30.69       NaN   2871340        1.856929e+09
# 2762        59.55       NaN   9483090        7.692215e+08
# 4021       463.26       NaN   1278214        1.548275e+08
# 5280       360.28       NaN   5398135        4.830000e+08
# 6539       142.81       NaN   8021045        5.756000e+08
# 7798        28.13       NaN   9559034        7.678136e+08
# 9057        35.82       NaN  39822021        7.822871e+08
# 10316       18.68       NaN      9590        9.076832e+06
# 11575        0.31       NaN    522459        6.522300e+07

# %%
# Now checking the data before we do Shares Outstanding*Market Cap

# Number of fundamental stock data rows we have;
print(Income_Data[Income_Data['Fiscal Year'] == 2019]['Ticker'].shape[0])

# Number of stock price data rows we have:
print(stock_prices_2019.shape[0])
# Out:
# 2170
# 2475

# %%
# Notice the size the fundamentals data and the stock price data don't match
# In the real work we frequently deal with imperfect data. 
# We will now cut down the data to make both dataframes correspond
# so that we can add a market cap column to create ratios like P/E, P/S etc.

# %%
# Use the .isin() dataframe function to first cut down the share prices dataframe to only contain stocks that are in the 
# Income statement dataframe.
stock_prices_2019 = stock_prices_2019[stock_prices_2019['Ticker'].isin(Income_Data_2019['Ticker'])]

# Do the same in the opposite direction. 
Income_Data_2019 = Income_Data_2019[Income_Data_2019['Ticker'].isin(stock_prices_2019['Ticker'])]
Income_Data_2019

# See the DataFrame
stock_prices_2019
# Out:
#         Ticker  SimFinId        Date     Open      Low     High    Close  \
# 962       GOOG        18  2020-03-02  1351.61  1326.82  1390.87  1389.11
# 2762      ATVI       243  2020-03-02    58.30    57.91    60.65    60.59
# 4021       BLK       914  2020-03-02   467.14   461.57   488.18   487.94
# 5280      ADBE     14099  2020-03-02   349.81   342.61   360.75   360.28
# 6539       MMM     22219  2020-03-02   151.34   148.37   153.43   153.02
# ...        ...       ...         ...      ...      ...      ...      ...
# 3118229   RVLV   1338983  2020-03-02    16.50    15.33    16.50    15.76
# 3119487   SMLR   1338984  2020-03-02    52.78    52.00    54.92    54.01
# 3120259   LPRO   1338985  2020-03-02    10.66    10.52    10.75    10.67
# 3123048    UAN   1340565  2020-03-02    20.20    19.80    20.90    19.80
# 3124307    AVD   1340567  2020-03-02    15.25    15.13    15.82    15.77
#
#          Adj. Close  Dividend   Volume  Shares Outstanding
# 962         1389.11       NaN  2431468         687286090.0
# 2762          59.55       NaN  9483090         769221524.0
# 4021         463.26       NaN  1278214         154827534.0
# 5280         360.28       NaN  5398135         483000000.0
# 6539         142.81       NaN  8021045         575600000.0
# ...             ...       ...      ...                 ...
# 3118229       15.76       NaN  1002290          69348313.0
# 3119487       54.01       NaN    28310           6527916.0
# 3120259       10.67       NaN    57306                 NaN
# 3123048       17.68       NaN    27333          11328297.0
# 3124307       15.63       NaN   125489          30186844.0
#
# [2067 rows x 11 columns]

# %%
Income_Data_2019 # Both stock_prices_2019 and Income_Data_2019 should have the same height
# Out:
#       Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 3          A     45846      USD         2019            FY  2019-10-31
# 10        AA    367153      USD         2019            FY  2019-12-31
# 16       AAL     68568      USD         2019            FY  2019-12-31
# 21      AAMC    847094      USD         2019            FY  2019-12-31
# 30      AAOI    671827      USD         2019            FY  2019-12-31
# ...      ...       ...      ...          ...           ...         ...
# 10866   ZUMZ     45730      USD         2019            FY  2020-01-31
# 10870    ZUO    994625      USD         2019            FY  2020-01-31
# 10875    ZVO    901866      USD         2019            FY  2019-12-31
# 10881   ZYNE    901704      USD         2019            FY  2019-12-31
# 10886   ZYXI    171401      USD         2019            FY  2019-12-31
#
#       Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 3       2019-12-19    2021-12-17     314000000.0       318000000.0  ...
# 10      2020-02-21    2022-02-24     185000000.0       185000000.0  ...
# 16      2020-02-19    2022-02-22     443363000.0       444269000.0  ...
# 21      2020-04-29    2021-03-03       1589952.0         1589952.0  ...
# 30      2020-02-28    2022-02-24      19982363.0        19982363.0  ...
# ...            ...           ...             ...               ...  ...
# 10866   2020-03-16    2021-03-15      25200000.0        25535000.0  ...
# 10870   2020-03-31    2022-03-28     111122000.0       111122000.0  ...
# 10875   2020-02-20    2021-02-24      29492000.0        29492000.0  ...
# 10881   2020-03-10    2022-03-01      22000203.0        22000203.0  ...
# 10886   2020-02-27    2021-02-25      35682900.0        37359300.0  ...
#
#        Interest Expense, Net  Pretax Income (Loss), Adj.  \
# 3                -38000000.0                   919000000
# 10              -121000000.0                   593000000
# 16              -968000000.0                  2256000000
# 21                       NaN                   -10392000
# 30                -4480000.0                   -51387000
# ...                      ...                         ...
# 10866              3654000.0                    90993000
# 10870              2712000.0                   -82953000
# 10875                    NaN                   -34117000
# 10881              1522138.0                   -32943583
# 10886                -5000.0                    11061000
#
#        Abnormal Gains (Losses)  Pretax Income (Loss)  \
# 3                          NaN             919000000
# 10               -1.031000e+09            -438000000
# 16                         NaN            2256000000
# 21                         NaN             -10392000
# 30                         NaN             -51387000
# ...                        ...                   ...
# 10866                      NaN              90993000
# 10870                      NaN             -82953000
# 10875            -2.146500e+07             -55582000
# 10881                      NaN             -32943583
# 10886             8.800000e+05              11941000
#
#        Income Tax (Expense) Benefit, Net  \
# 3                            152000000.0
# 10                          -415000000.0
# 16                          -570000000.0
# 21                             -165000.0
# 30                           -14662000.0
# ...                                  ...
# 10866                        -24112000.0
# 10870                          -441000.0
# 10875                           770000.0
# 10881                                NaN
# 10886                         -2449000.0
#
#        Income (Loss) from Continuing Operations  \
# 3                                    1071000000
# 10                                   -853000000
# 16                                   1686000000
# 21                                    -10557000
# 30                                    -66049000
# ...                                         ...
# 10866                                  66881000
# 10870                                 -83394000
# 10875                                 -54812000
# 10881                                 -32943583
# 10886                                   9492000
#
#        Net Extraordinary Gains (Losses)  Net Income  Net Income (Common)  \
# 3                                   NaN  1071000000           1071000000
# 10                                  NaN -1125000000          -1125000000
# 16                                  NaN  1686000000           1686000000
# 21                            7944000.0    -2613000             -2819000
# 30                                  NaN   -66049000            -66049000
# ...                                 ...         ...                  ...
# 10866                               NaN    66881000             66881000
# 10870                               NaN   -83394000            -83394000
# 10875                               NaN   -54812000            -54812000
# 10881                               NaN   -32943583            -32943583
# 10886                               NaN     9492000              9492000
#
#          Market Cap
# 3      2.458458e+10
# 10     2.593700e+09
# 16     8.463324e+09
# 21     3.307100e+07
# 30     1.788421e+08
# ...             ...
# 10866  6.817845e+08
# 10870  1.481256e+09
# 10875  4.659736e+07
# 10881  9.812091e+07
# 10886  4.382246e+08
#
# [2067 rows x 29 columns]

# %%
# We have lost some rows in our dataframes in keeping only common stock tickers.
# Arrange both income and stock price dataframes alphabetically so the rows correspond.
stock_prices_2019 = stock_prices_2019.sort_values(by=['Ticker'])
Income_Data_2019 = Income_Data_2019.sort_values(by=['Ticker'])

# Make the stock_data DataFrame from the Income Data and add a Market Cap series.
stock_data_2019 = Income_Data_2019
stock_data_2019['Market Cap'] = Income_Data_2019['Shares (Diluted)'].values * stock_prices_2019['Open'].values

# %%
# Take a look at the distribution of Market Caps in the stock market with a histogram.
# use a large number of hisogram bins and a log scale, this will enable you to view the data better.
# You will see that there are many at the low end, and very few super large corporations in America

stock_data_2019['Market Cap'].hist(bins=100, log=True);
# Try to format this graph yourself with title, axis labels and so on.

# %% [markdown]
# ## Finding Stocks With Market Cap, P/E Ratio Screens and More

# %%
# Let's see which companies are the largest by market cap.
stock_data_2019[['Ticker',
                'Currency',
                'Fiscal Year', 
                'Report Date',
                'Publish Date',
                'Restated Date',
                'Net Income',
                'Selling, General & Administrative',
                'Gross Profit',
                'Market Cap']].sort_values(by=['Market Cap'], 
                                             ascending=False).head(???)
# Out:
#       Ticker Currency  Fiscal Year Report Date Publish Date Restated Date  \
# 45      AAPL      USD         2019  2019-09-30   2019-10-31    2021-10-29
# 6441    MSFT      USD         2019  2019-06-30   2019-08-01    2021-07-29
# 1516   BRK-A      USD         2019  2019-12-31   2020-02-24    2022-02-28
# 4243    GOOG      USD         2019  2019-12-31   2020-02-04    2022-02-02
# 659     AMZN      USD         2019  2019-12-31   2020-01-31    2022-02-04
# 3636      FB      USD         2019  2019-12-31   2020-01-30    2022-02-03
# 10051      V      USD         2019  2019-09-30   2019-11-14    2021-11-18
# 9501      TM      USD         2019  2020-03-31   2020-06-24    2021-06-24
# 5229     JNJ      USD         2019  2019-12-31   2020-02-18    2022-02-17
# 10535    WMT      USD         2019  2020-01-31   2020-03-20    2022-03-18
#
#         Net Income  Selling, General & Administrative  Gross Profit  \
# 45     55256000000                      -1.824500e+10  9.839200e+10
# 6441   39240000000                      -2.309800e+10  8.293300e+10
# 1516   81417000000                      -1.922600e+10  5.223700e+10
# 4243   34343000000                      -2.801500e+10  8.996100e+10
# 659    11588000000                      -2.408100e+10  1.149860e+11
# 3636   18485000000                      -2.034100e+10  5.792700e+10
# 10051  12080000000                      -5.745000e+09           NaN
# 9501   18734816491                      -2.743747e+10  4.951313e+10
# 5229   15119000000                      -2.217800e+10  5.450300e+10
# 10535  14881000000                      -1.087910e+11  1.293590e+11
#
#          Market Cap
# 45     1.312295e+12
# 6441   1.281648e+12
# 1516   1.026360e+12
# 4243   1.007062e+12
# 659    9.608710e+11
# 3636   5.580303e+11
# 10051  5.075823e+11
# 9501   4.119881e+11
# 5229   3.617900e+11
# 10535  3.085968e+11

# %%
'''
It's no surprise that AAPL and AMZN are present, 
earlier we found that they had the largest gross profits.

When picking stocks with fundamentals we would like the most bang/buck.

Let's create a P/E ratio, and find some stocks using that.
'''

# %%
# Creating a P/E ratio, here we have clipped the result to +=1000.
stock_data_2019[?????] = (stock_data_2019['Market Cap']/stock_data_2019['Net Income']).clip(-1000,1000)
stock_data_2019['P/E'].hist(bins=100, log=True);

# %%
# Let's see which companies are lowest by P/E ratio.
# We want t remove stocks with P/E < 0 too.

stock_data_2019[['Ticker',
                'Currency',
                'Fiscal Year', 
                'Report Date',
                'Publish Date',
                'Restated Date',
                'Net Income',
                'Selling, General & Administrative',
                'Gross Profit',
                'Market Cap',
                'P/E']][stock_data_2019['P/E'] > 0].sort_values(by=['P/E'],
                                    ascending=True).head(10)
# Out:
#       Ticker Currency  Fiscal Year Report Date Publish Date Restated Date  \
# 8123     RHE      USD         2019  2019-12-31   2020-03-27    2021-03-29
# 1957     CGA      USD         2019  2019-06-30   2019-10-15    2020-12-07
# 10666   XBIT      USD         2019  2019-12-31   2020-03-16    2022-03-15
# 9202     SWN      USD         2019  2019-12-31   2020-02-27    2022-03-01
# 5411    KODK      USD         2019  2019-12-31   2020-03-17    2022-03-15
# 5529   LBTYA      USD         2019  2019-12-31   2020-03-27    2022-02-17
# 9054    SSNT      USD         2019  2019-12-31   2020-03-26    2021-03-25
# 6854     NRG      USD         2019  2019-12-31   2020-02-27    2022-02-24
# 650     AMTD      USD         2019  2019-09-30   2020-01-27    2020-01-27
# 838     ARLP      USD         2019  2019-12-31   2020-02-20    2022-02-25
#
#         Net Income  Selling, General & Administrative  Gross Profit  \
# 8123       5500000                      -3.192000e+06           NaN
# 1957      11590395                      -4.583793e+07  6.464268e+07
# 10666    668629000                      -7.143000e+06           NaN
# 9202     891000000                      -1.486000e+09           NaN
# 5411     116000000                      -2.110000e+08  1.820000e+08
# 5529   11521400000                      -3.623400e+09  7.985000e+09
# 9054       6794226                      -1.561171e+07  1.467845e+07
# 6854    4438000000                      -7.600000e+08  2.518000e+09
# 650     2208000000                      -2.545000e+09           NaN
# 838      399414000                      -7.299700e+07  6.801170e+08
#
#          Market Cap       P/E
# 8123   2.346320e+06  0.426604
# 1957   7.590305e+06  0.654879
# 10666  5.692661e+08  0.851393
# 9202   7.781514e+08  0.873346
# 5411   1.337300e+08  1.152845
# 5529   1.374182e+10  1.192721
# 9054   1.332245e+07  1.960849
# 6854   8.793840e+09  1.981487
# 650    4.740070e+09  2.146771
# 838    8.700153e+08  2.178229

# %%
# There are some companies with a market cap of less than $10 million, which is very low.
# A lot of people consider these micro-cap stocks to be very risky, 
# so it might be a good idea to filter them out


# RHE is at the top of the list. 
# With a low P/E ratio, the market seems quite pessimistic abouyt this company.
# Let's see if that's justified by plotting the revenue and earnings over time.
Income_Data[Income_Data['Ticker']=='RHE'].plot.bar(x='Report Date', 
                                                    y=['Revenue',
                                                       'Net Income'], 
                                                    rot=0, 
                                                    subplots=True,
                                                    grid='on',
                                                    title='RHE Revenue and Net Income');

# %%
# The revenue seems to be declining steadily, which doesn't look good.
# The P/E is an obvious measure of value, so it's not a surprise that stocks with low P/E
# look pretty bad.

# %% [markdown]
# End of Exercise 6.

# %% [markdown]
# # Pandas Data Reader

# %%
import pandas as pd
import pandas_datareader.data as pdr # Be sure this is installed from anaconda
from matplotlib import pyplot as plt

# Start and end dates
start = pd.to_datetime('2019-05-01')
end = pd.to_datetime('2020-05-01')

# Use the Pandas DataReader
tickerData = pdr.DataReader('SPY', 'yahoo', start, end);

# Plot the data
plt.plot(tickerData['Open']);
plt.grid();
plt.xlabel('Date');
plt.ylabel('SPY value');

# %%
tickerData
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2019-05-01  294.950012  291.799988  294.720001  291.809998   71671900.0
# 2019-05-02  292.700012  289.519989  291.679993  291.179993   65030200.0
# 2019-05-03  294.339996  291.299988  292.820007  294.029999   56543700.0
# 2019-05-06  293.309998  288.899994  289.250000  292.820007  107198100.0
# 2019-05-07  290.809998  285.809998  290.149994  287.929993  144729900.0
# ...                ...         ...         ...         ...          ...
# 2020-04-27  288.269989  284.619995  285.119995  287.049988   77896600.0
# 2020-04-28  291.399994  285.399994  291.019989  285.730011  105270000.0
# 2020-04-29  294.880005  290.410004  291.529999  293.209991  118745600.0
# 2020-04-30  293.320007  288.589996  291.709991  290.480011  122901700.0
# 2020-05-01  290.660004  281.519989  285.309998  282.790009  125180000.0
#
#              Adj Close
# Date
# 2019-05-01  282.375183
# 2019-05-02  281.765503
# 2019-05-03  284.523407
# 2019-05-06  283.352539
# 2019-05-07  278.620605
# ...                ...
# 2020-04-27  283.444672
# 2020-04-28  282.141235
# 2020-04-29  289.527283
# 2020-04-30  286.831604
# 2020-05-01  279.238159
#
# [254 rows x 6 columns]

# %% [markdown]
# ### iloc and loc

# %%
# .iloc[] selects rows like a list

# %%
tickerData.iloc[-5:] #last 5 rows
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2020-04-27  288.269989  284.619995  285.119995  287.049988   77896600.0
# 2020-04-28  291.399994  285.399994  291.019989  285.730011  105270000.0
# 2020-04-29  294.880005  290.410004  291.529999  293.209991  118745600.0
# 2020-04-30  293.320007  288.589996  291.709991  290.480011  122901700.0
# 2020-05-01  290.660004  281.519989  285.309998  282.790009  125180000.0
#
#              Adj Close
# Date
# 2020-04-27  278.849762
# 2020-04-28  277.567505
# 2020-04-29  284.833832
# 2020-04-30  282.181824
# 2020-05-01  274.711517

# %%
tickerData.iloc[:5] #first 5 rows
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2019-05-01  294.950012  291.799988  294.720001  291.809998   71671900.0
# 2019-05-02  292.700012  289.519989  291.679993  291.179993   65030200.0
# 2019-05-03  294.339996  291.299988  292.820007  294.029999   56543700.0
# 2019-05-06  293.309998  288.899994  289.250000  292.820007  107198100.0
# 2019-05-07  290.809998  285.809998  290.149994  287.929993  144729900.0
#
#              Adj Close
# Date
# 2019-05-01  282.375183
# 2019-05-02  281.765503
# 2019-05-03  284.523407
# 2019-05-06  283.352539
# 2019-05-07  278.620605

# %%
tickerData.iloc[207] # row 207
# Out:
# High         3.181100e+02
# Low          3.107000e+02
# Open         3.141800e+02
# Close        3.115000e+02
# Volume       1.947738e+08
# Adj Close    3.057895e+02
# Name: 2020-02-26 00:00:00, dtype: float64

# %%
# .loc[] selects rows using the index. 
# With Timeseries data like this, the index is a date, not a number.
tickerData.loc['2019-05-01']
# Out:
# High         2.949500e+02
# Low          2.918000e+02
# Open         2.947200e+02
# Close        2.918100e+02
# Volume       7.167190e+07
# Adj Close    2.823752e+02
# Name: 2019-05-01 00:00:00, dtype: float64

# %%
tickerData.loc[tickerData.index>'2020-01-01']['Close'].plot()
plt.grid() # Add a grid to the plot.
